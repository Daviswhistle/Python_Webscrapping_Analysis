# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.2
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: D:\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, intake, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract
# WARNING: Skipping D:\anaconda3\Lib\site-packages\certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping D:\anaconda3\Lib\site-packages\conda-24.5.0.dist-info due to invalid metadata entry 'name'

# %%
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page:
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: D:\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert
# WARNING: Skipping D:\anaconda3\Lib\site-packages\certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping D:\anaconda3\Lib\site-packages\conda-24.5.0.dist-info due to invalid metadata entry 'name'

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
print(f'request ver {requests.__version__}' )
print('beautifulsoup {}'.format(bs4.__version__))
# Out:
# request ver 2.32.2
# beautifulsoup 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스
req_param = {
    'sid': 105
}
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
# print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
}

# requests 모듈을 사용한 http 통신
res = requests.get(url, headers=req_header)
# print(type(res))
# print(res.status_code)
# print(res.ok)
if res.ok:
    html = res.text
    # parsing을 하기 위해 BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, "html.parser")
    # print(type(soup))
    # print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/article']")))
    # print(len(soup.select("div.sa_text a.sa_text_title")))
    atag_list = soup.select("div.sa_text a.sa_text_title")
    # print(type(atag_list))
    for atag in atag_list:
        # print(type(atag))
        # print(atag)
        # strip: 공백 제거 함수
        title = atag.text.strip()
        url = atag['href']
        print(f'뉴스 제목: {title}\n링크: {url}')
        print('--------------')
else:
    print(f'Error 발생: {res.status_code}')
# Out:
# 뉴스 제목: "애플, 9월엔 인텔리전스 없이 아이폰16만 나온다"
# 링크: https://n.news.naver.com/mnews/article/092/0002340917
# --------------
# 뉴스 제목: 카카오헬스케어, '연구 협력 네트워크' 17개 병원으로 확대
# 링크: https://n.news.naver.com/mnews/article/215/0001173880
# --------------
# 뉴스 제목: 배터리 화재 키우는 '열폭주' 억제 방법 찾았다
# 링크: https://n.news.naver.com/mnews/article/584/0000028179
# --------------
# 뉴스 제목: 게임산업協, 게임 인식 개선 위한 리터러시 교육 안내서 발간
# 링크: https://n.news.naver.com/mnews/article/003/0012709567
# --------------
# 뉴스 제목: SKT, 세계적 정보검색 학회서 AI기술 우수논문상 수상
# 링크: https://n.news.naver.com/mnews/article/008/0005072836
# --------------
# 뉴스 제목: 한국형 스타이펜드, 내년 지급 초읽기…대학 관리기관 신청공고
# 링크: https://n.news.naver.com/mnews/article/008/0005073016
# --------------
# 뉴스 제목: SK C&C, 베트남 ICT기업과 디지털 ESG 사업 협력
# 링크: https://n.news.naver.com/mnews/article/011/0004375947
# --------------
# 뉴스 제목: 포스텍, 교수 정착지원금 최대 10억원으로…"우수 석학 유치"
# 링크: https://n.news.naver.com/mnews/article/001/0014854962
# --------------
# 뉴스 제목: 코스피·코스닥 줄이어 서킷브레이커 발동
# 링크: https://n.news.naver.com/mnews/article/092/0002340932
# --------------
# 뉴스 제목: 엔씨소프트, 적자 면했다… 2분기 영업이익 88억원
# 링크: https://n.news.naver.com/mnews/article/138/0002179213
# --------------
# 뉴스 제목: 韓, 반도체 대중 수출 늘자… 中 “美 수출 제재 한계 드러나”
# 링크: https://n.news.naver.com/mnews/article/366/0001009937
# --------------
# 뉴스 제목: ‘아재 입맛’인 줄 알았는데…믹스커피 MZ 업고 뜨나
# 링크: https://n.news.naver.com/mnews/article/092/0002340930
# --------------
# 뉴스 제목: 네이버 '쇼핑 검색광고' 타고 온 '파워적립' 8년 만에 폐지
# 링크: https://n.news.naver.com/mnews/article/018/0005805500
# --------------
# 뉴스 제목: 한국 양궁 금메달 5개 '싹쓸이'...비결은?
# 링크: https://n.news.naver.com/mnews/article/092/0002340929
# --------------
# 뉴스 제목: [단독] 찜통더위 부른 북태평양 고기압…한중일 손잡고 예측 정확성 높인다
# 링크: https://n.news.naver.com/mnews/article/366/0001009933
# --------------
# 뉴스 제목: 곤두박질치는 비트코인…'트럼프 약발' 보단 'R의 공포'
# 링크: https://n.news.naver.com/mnews/article/018/0005805497
# --------------
# 뉴스 제목: 이통3사 2분기 합산 영업익 예상 1.3조…전환지원금 타격 적었다
# 링크: https://n.news.naver.com/mnews/article/003/0012710549
# --------------
# 뉴스 제목: 배터리 화재 키우는 '열폭주' 억제 방법 찾았다
# 링크: https://n.news.naver.com/mnews/article/584/0000028179
# --------------
# 뉴스 제목: 티빙, 토종 OTT 1위 굳히기.. 쿠플, EPL로 만회 나선다
# 링크: https://n.news.naver.com/mnews/article/014/0005223409
# --------------
# 뉴스 제목: M7 주가폭락에 실망한 투자자…"인내심 한계 달했다"
# 링크: https://n.news.naver.com/mnews/article/092/0002340926
# --------------
# 뉴스 제목: 유라클, 수요예측 경쟁률 1065.8대 1…공모가 2만1000원 확정
# 링크: https://n.news.naver.com/mnews/article/138/0002179208
# --------------
# 뉴스 제목: "뭘로 결제했더라"…티메프 환불, 페이·카드 희비 엇갈린다
# 링크: https://n.news.naver.com/mnews/article/018/0005805482
# --------------
# 뉴스 제목: 엔씨, 빅게임스튜디오 370억 규모 지분·판권 투자
# 링크: https://n.news.naver.com/mnews/article/003/0012710504
# --------------
# 뉴스 제목: 아이폰, 이제야 한국 대우하나…신작 '1차 출시국' 포함된다
# 링크: https://n.news.naver.com/mnews/article/015/0005018184
# --------------
# 뉴스 제목: 혼돈의 방송통신위원회와 ‘애국자가 없는 세상’
# 링크: https://n.news.naver.com/mnews/article/092/0002340921
# --------------
# 뉴스 제목: 청라 화재서 촉발된 '中 배터리 포비아'…韓 3사 대체 가능성은 [소부장박대리]
# 링크: https://n.news.naver.com/mnews/article/138/0002179205
# --------------
# 뉴스 제목: 말라리아·일본뇌염 모기 2배 넘게 급증…가장 확실한 예방법은
# 링크: https://n.news.naver.com/mnews/article/421/0007710891
# --------------
# 뉴스 제목: “편의점 알바보다 열악한 처우” 이공계 석박사…연구생활장려금 지급, 숨통 트일까
# 링크: https://n.news.naver.com/mnews/article/016/0002345560
# --------------
# 뉴스 제목: 전기차 배터리 열폭주 막을 방법 찾았다
# 링크: https://n.news.naver.com/mnews/article/366/0001009912
# --------------
# 뉴스 제목: "美 상무부, 자율주행차 중국SW 사용 금지 규정 이달 발표 예정"
# 링크: https://n.news.naver.com/mnews/article/029/0002892817
# --------------
# 뉴스 제목: 이공계 대학원생에 매달 80~110만원 지급…연구비 관리제도 개선
# 링크: https://n.news.naver.com/mnews/article/001/0014855246
# --------------
# 뉴스 제목: 全 종목 '금메달' 석권 양궁…정의선 회장 40년 함께했다
# 링크: https://n.news.naver.com/mnews/article/092/0002340919
# --------------
# 뉴스 제목: "언제까지 이렇게 덥나"…기상청 대신 인기 폭발한 날씨앱
# 링크: https://n.news.naver.com/mnews/article/008/0005073035
# --------------
# 뉴스 제목: 美, 자율주행차에 중국산 SW·통신모듈 탑재 금지 추진
# 링크: https://n.news.naver.com/mnews/article/011/0004376131
# --------------
# 뉴스 제목: 韓 해킹한 자료로 공장·지방개발 하려는 北... 北해커들 이곳 노린다
# 링크: https://n.news.naver.com/mnews/article/008/0005073031
# --------------
# 뉴스 제목: 코오롱바이오텍, 골관절염 치료제 ‘TG-C’ 대량 생산 공정 개발
# 링크: https://n.news.naver.com/mnews/article/018/0005805447
# --------------
# 뉴스 제목: “스마트폰 시장 3년 만에 성장세...삼성, 애플과 격차 벌릴 것”
# 링크: https://n.news.naver.com/mnews/article/366/0001009904
# --------------
# 뉴스 제목: [제약바이오] 종근당, 바르는 소염진통제 케펨겔 출시 外
# 링크: https://n.news.naver.com/mnews/article/092/0002340918
# --------------
# 뉴스 제목: '아마란스10' 200% 늘어난 더존비즈온, 하반기도 맑음
# 링크: https://n.news.naver.com/mnews/article/014/0005223355
# --------------
# 뉴스 제목: 더존비즈온, 매출·영업이익 '쑥쑥'…"핵심사업 고른 성장"
# 링크: https://n.news.naver.com/mnews/article/648/0000027909
# --------------
# 뉴스 제목: 애플, 버터플라이 키보드 집단소송 美 소비자에 보상금
# 링크: https://n.news.naver.com/mnews/article/366/0001009897
# --------------
# 뉴스 제목: ‘살 파먹는 세균’ 잡는 약물 개발 [달콤한 사이언스]
# 링크: https://n.news.naver.com/mnews/article/081/0003470020
# --------------
# 뉴스 제목: “이공계 석·박사 월 80~110만 원”…‘한국형 스타이펜드’ 윤곽 나왔다
# 링크: https://n.news.naver.com/mnews/article/056/0011775233
# --------------
# 뉴스 제목: 자체 개발 SQL로 승부하는 '스마트마인드' [과기대X글로벌]
# 링크: https://n.news.naver.com/mnews/article/020/0003580328
# --------------

# %%
section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

def print_news(sid, section):    
    # 요청 Parameter
    req_param = {
    'sid': sid
    }
    url = 'https://news.naver.com/section/{sid}'.format(**req_param)
    
    print(f'======> {url} {section} 뉴스 <======')
    
    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
    }

    res = requests.get(url, headers=req_header)

    if res.ok:
        html = res.text
        soup = BeautifulSoup(html, "html.parser")
        atag_list = soup.select("div.sa_text a.sa_text_title")
        for atag in atag_list:
            title = atag.text.strip()
            url = atag['href']
            print(f'뉴스 제목: {title}\n링크: {url}')
            print('--------------')
    else:
        print(f'Error 발생: {res.status_code}')

# %%
print_news(101,section_dict[101])
# Out:
# ======> https://news.naver.com/section/101 경제 뉴스 <======
# 뉴스 제목: 여자 양궁 전 종목 석권…정의선 회장, '맏언니' 전훈영 찾아 격려
# 링크: https://n.news.naver.com/mnews/article/374/0000395946
# --------------
# 뉴스 제목: 김병환 "금융안정 위해 부채중심 구조 개선해야"
# 링크: https://n.news.naver.com/mnews/article/018/0005805213
# --------------
# 뉴스 제목: 엄습하는 미국발 경기침체 공포‥최상목 부총리 "높은 경계심, 긴밀대응"
# 링크: https://n.news.naver.com/mnews/article/214/0001365878
# --------------
# 뉴스 제목: "원전에 1조2000억 투자, 주주배당 규모 유지" 두산의 주주달래기 성공할까 [biz-플러스]
# 링크: https://n.news.naver.com/mnews/article/011/0004375877
# --------------
# 뉴스 제목: 대출금리 잇따라 올린 시중은행들, 예금금리는 최대 0.2%p↓
# 링크: https://n.news.naver.com/mnews/article/056/0011774708
# --------------
# 뉴스 제목: 경총, 노란봉투법 본회의 통과 강행한 야당 비난…대통령 거부권 건의
# 링크: https://n.news.naver.com/mnews/article/119/0002858804
# --------------
# 뉴스 제목: 채권왕 빌 그로스 "버핏 주식 매도는 주가 정점 신호"
# 링크: https://n.news.naver.com/mnews/article/421/0007709703
# --------------
# 뉴스 제목: 우리투자증권 "10년 내 초대형IB 도약..2~3년 내 2차 M&A 고려"
# 링크: https://n.news.naver.com/mnews/article/014/0005223324
# --------------
# 뉴스 제목: '플랫폼 종사자' 88만 명...월평균 145만 원 벌어
# 링크: https://n.news.naver.com/mnews/article/052/0002070299
# --------------
# 뉴스 제목: 삼성전자 노조, 시민단체 반올림과 산재 대응 업무협약
# 링크: https://n.news.naver.com/mnews/article/056/0011775279
# --------------
# 뉴스 제목: 삼전·SK하닉 -10%··· 코스피 역대 최대 낙폭 경신
# 링크: https://n.news.naver.com/mnews/article/009/0005345611
# --------------
# 뉴스 제목: 엔비디아 블랙웰 지연·인텔 파운드리 적자…"삼성전자에 기회"
# 링크: https://n.news.naver.com/mnews/article/029/0002892855
# --------------
# 뉴스 제목: 대장주도 피할 수 없었던 블랙먼데이…10% 급락한 삼전·닉스
# 링크: https://n.news.naver.com/mnews/article/008/0005073123
# --------------
# 뉴스 제목: '대폭락의 날' 파랗게 질린 코스피…시총 235조 증발했다
# 링크: https://n.news.naver.com/mnews/article/015/0005018215
# --------------
# 뉴스 제목: “머리 한방 맞은 듯, 멍했던 하루”…삼성전자·기아 10% 폭락, 국장 최악의 날
# 링크: https://n.news.naver.com/mnews/article/009/0005345608
# --------------
# 뉴스 제목: "개미들 비명"…삼성전자, 10%대 폭락(종합)
# 링크: https://n.news.naver.com/mnews/article/003/0012710705
# --------------
# 뉴스 제목: K밸류업 무너지나…방어株 은행도 `우수수`
# 링크: https://n.news.naver.com/mnews/article/029/0002892852
# --------------
# 뉴스 제목: `中 배터리 벤츠` 화재로 부상한 `전고체 배터리`…LG엔솔·SK온, 개발 박차
# 링크: https://n.news.naver.com/mnews/article/029/0002892851
# --------------
# 뉴스 제목: [이슈플러스]美 경기 지표 악화에…비트코인 5만 달러 붕괴
# 링크: https://n.news.naver.com/mnews/article/030/0003229229
# --------------
# 뉴스 제목: 中 안방보험 파산에 우리금융, 동양·ABL생명 패키지 인수 탄력 받나
# 링크: https://n.news.naver.com/mnews/article/366/0001009953
# --------------
# 뉴스 제목: ‘3차 입찰’ 용산 산호아파트 재건축, DL이앤씨 빠지고 롯데건설 ‘관심’
# 링크: https://n.news.naver.com/mnews/article/366/0001009952
# --------------
# 뉴스 제목: 최태원 "HBM 안주 말고 새 먹거리 고민할 때"
# 링크: https://n.news.naver.com/mnews/article/018/0005805544
# --------------
# 뉴스 제목: 최태원 회장 하이닉스 반도체 공장 전격 방문, 왜?
# 링크: https://n.news.naver.com/mnews/article/047/0002442025
# --------------
# 뉴스 제목: SK 최태원 장남 다니는 이곳, 최재원 장남도 입사
# 링크: https://n.news.naver.com/mnews/article/003/0012710691
# --------------
# 뉴스 제목: 국내 증시 장중 2400선도 무너져…서킷브레이커 발동
# 링크: https://n.news.naver.com/mnews/article/662/0000049112
# --------------
# 뉴스 제목: '아직 배고픈' 최태원…"HBM 이을 차세대 반도체" 주문
# 링크: https://n.news.naver.com/mnews/article/648/0000027916
# --------------
# 뉴스 제목: 검은 월요일 현실화…외국인 몰린 '반·디·배' 대장주 '휘청'
# 링크: https://n.news.naver.com/mnews/article/138/0002179217
# --------------
# 뉴스 제목: 코스피 8%, 닛케이 12% 급락…비트코인 곤두박질
# 링크: https://n.news.naver.com/mnews/article/079/0003924772
# --------------
# 뉴스 제목: '최악의 하루' 코스피 역대 최대 낙폭…亞증시도 줄패닉
# 링크: https://n.news.naver.com/mnews/article/629/0000310639
# --------------
# 뉴스 제목: ‘6만전자’ 눈앞…코스피 8% 하락 ‘최악의 날’
# 링크: https://n.news.naver.com/mnews/article/081/0003470079
# --------------
# 뉴스 제목: [코스피 마감] '공포의 월요일' 8%대 폭락에 2400선…‘역대 최대 낙폭’
# 링크: https://n.news.naver.com/mnews/article/018/0005805541
# --------------
# 뉴스 제목: “엔비디아는 오른 거라도 있지”...삼전·SK하이닉스 10% 폭락에 망연자실
# 링크: https://n.news.naver.com/mnews/article/009/0005345601
# --------------
# 뉴스 제목: 중소형 방산株, K-증시 폭락 부채질 중동 사태에 나 홀로 강세 [투자360]
# 링크: https://n.news.naver.com/mnews/article/016/0002345623
# --------------
# 뉴스 제목: [르포] '초격차' 삼바, 휴가철에도 멈추지 않고 24시간 풀가동…수주물량 생산 이상無
# 링크: https://n.news.naver.com/mnews/article/011/0004376170
# --------------
# 뉴스 제목: 비트코인 한 때 5만 달러 붕괴… 이더리움 20% ↓
# 링크: https://n.news.naver.com/mnews/article/011/0004376169
# --------------
# 뉴스 제목: 올해 햄버거값 줄인상에도…맘스터치 나홀로 동결 "인상계획 無"
# 링크: https://n.news.naver.com/mnews/article/003/0012710670
# --------------
# 뉴스 제목: 美 침체 우려에 주가 폭락...'동반' 서킷브레이커까지
# 링크: https://n.news.naver.com/mnews/article/052/0002070370
# --------------
# 뉴스 제목: 최재원 SK 부회장 장남, E&S 美 법인 입사…사촌동생과 한솥밥
# 링크: https://n.news.naver.com/mnews/article/008/0005073113
# --------------
# 뉴스 제목: 서울 집값 들썩이자 뜨거워진 부동산 청약·경매
# 링크: https://n.news.naver.com/mnews/article/025/0003377933
# --------------
# 뉴스 제목: '아시아 증시 블랙 먼데이'…은행권, 살아나는 '홍콩 ELS' 악몽
# 링크: https://n.news.naver.com/mnews/article/008/0005073111
# --------------
# 뉴스 제목: 자율구조조정 승인되자 움직이는 구영배…계열사 대표 회동 추진
# 링크: https://n.news.naver.com/mnews/article/001/0014855523
# --------------
# 뉴스 제목: 삼성전자 10%대 급락…2008년 금융위기 이후 최대 낙폭
# 링크: https://n.news.naver.com/mnews/article/277/0005455227
# --------------
# 뉴스 제목: [현장연결] 또다시 1인 체제…김태규 방통위원장 직무대행 입장 발표
# 링크: https://n.news.naver.com/mnews/article/422/0000674755
# --------------
# 뉴스 제목: 美 대선 정국에 VIX지수 더 뛴다···“소비재·유틸리티·방산주로 ‘지키는 투자’ 해야”
# 링크: https://n.news.naver.com/mnews/article/009/0005345598
# --------------
# 뉴스 제목: 점점 커지는 엔캐리 트레이드 청산 공포…"변동성 더 커질수도"
# 링크: https://n.news.naver.com/mnews/article/008/0005073109
# --------------
# 뉴스 제목: [코스닥 마감]침체 공포에 700선 붕괴…역대 10번째 서킷브레이커
# 링크: https://n.news.naver.com/mnews/article/018/0005805523
# --------------

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=798173&no=5&amp;weekday=thu'
}
img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]
for img_url in img_urls:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        # binary data 추출
        img_data = res.content
        
        #url에서 file name 가져오기
        file_name = os.path.basename(img_url)
        with open(file_name, 'wb') as file:
            print(f'writing to {file_name} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error 발생: {res.status_code}')
# Out:
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg (299,319 bytes)
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg (163,333 bytes)
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg (182,530 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=817945&no=37&week=mon'
req_header = {
    'referer': webtoon_url
}

#jpg image 파일명을 먼저 알아내야 함
res = requests.get(webtoon_url)
if res.ok: #200
    soup = BeautifulSoup(res.text, 'html.parser')
    # print(len(soup.select("div.wt_viewer img[src$='.jpg']")))
    img_tag_list = soup.select("div.wt_viewer img[src$='.jpg']")

    #declaring list of image filenames
    img_url_list = []
    for img_tag in img_tag_list:
        # print(img_tag['src'])
        #extracting src attribute of image tag and appending to the list
        img_url_list.append(img_tag['src'])

    image_dir_name = 'img'
    #create new img directory if img directory doesn't exist
    if not os.path.isdir(image_dir_name):
        os.mkdir(image_dir_name)

    for idx, img_url in enumerate(img_url_list, 1):
        res = requests.get(img_url, headers=req_header)
        if res.ok:
            # binary data 추출
            img_data = res.content
        
            #url에서 file name 가져오기
            file_name = os.path.basename(img_url)
            dir_name = os.path.join(image_dir_name, file_name)
            with open(dir_name, 'wb') as file:
                print(f'writing to {file_name} ({len(img_data):,} bytes)')
                file.write(img_data)
        else:
            print(f'Error 발생: {res.status_code}')
    
else:
    print(res.status_code)
# Out:
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_1.jpg (128,897 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_2.jpg (143,194 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_3.jpg (101,900 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_4.jpg (112,007 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_5.jpg (190,876 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_6.jpg (134,590 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_7.jpg (132,910 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_8.jpg (174,434 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_9.jpg (88,576 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_10.jpg (177,240 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_11.jpg (95,130 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_12.jpg (109,718 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_13.jpg (144,476 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_14.jpg (127,739 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_15.jpg (143,133 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_16.jpg (159,328 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_17.jpg (139,300 bytes)
# writing to 20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_18.jpg (54,967 bytes)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %% [markdown]
# ### 4. 단축 URL 생성하는 Open API 사용하기
# * urllib 사용

# %%
import os
import sys
import urllib.request

client_id = "V" # 개발자센터에서 발급받은 Client ID 값
client_secret = "y_" # 개발자센터에서 발급받은 Client Secret 값
encText = urllib.parse.quote("https://drive.google.com/drive/u/0/folders/1V_DK7Px5w_niEKLlWhDr_GPgIYHG3Du-")
data = "url=" + encText
url = "https://openapi.naver.com/v1/util/shorturl"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
import requests

client_id = "V" # 개발자센터에서 발급받은 Client ID 값
client_secret = "y_" # 개발자센터에서 발급받은 Client Secret 값

origin_url = "https://drive.google.com/drive/u/0/folders/1V_DK7Px5w_niEKLlWhDr_GPgIYHG3Du-"

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': 'V',
    'X-Naver-Client-Secret': 'y_',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'

res = requests.get(url, params=payload, headers=headers)
items_data = res.json()['items']
#print(items_data)

items_list = list()
item_list = []
for item in items_data:
#     print(item)
    item_list.append(item['title'])
    item_list.append(item['bloggername'])
    item_list.append(item['description'])
    item_list.append(item['bloggerlink'])
    item_list.append(item['link'])

    items_list.append(item_list)
    item_list = []

print(items_list)

with open('data/nhnblog.txt','w',encoding="utf-8")as file:
    for items in items_list:
        for item in items:
            item = item + '\n'
            file.write(item)
        file.write('-'*150+'\n')
